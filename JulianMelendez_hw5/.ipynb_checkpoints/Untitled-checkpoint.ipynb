# %%
# %pylab inline
obs_data = loadtxt("RadialVelocities.dat")
x_obs = obs_data[:,0]
y_obs = obs_data[:,1]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
scatter(x_obs,y_obs)

# %%
def likelihood(y_obs, y_model):
    error = y_obs-y_model
    chi_squared = (1.0/2.0)*sum((y_obs-y_model)**2)
    return exp(-chi_squared)
